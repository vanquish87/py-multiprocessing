# %%
import time

start = time.perf_counter()


def do_something():
    print('Sleeping 1 second.....')
    time.sleep(1)
    print('done sleeping')

# running synchoronously
do_something()
do_something()

finish = time.perf_counter()

print(f'Finished in {round((finish - start), 2)} Seconds(s)')
# Out:
# Sleeping 1 second.....
# done sleeping
# Sleeping 1 second.....
# done sleeping
# Finished in 2.02 Seconds(s)

# %% [markdown]
# Using plain MultiProcessing

# %%
import time
import multiprocessing

start = time.perf_counter()


def do_something():
    print('Sleeping 1 second.....')
    time.sleep(1)
    print('done sleeping')

p1 = multiprocessing.Process(target=do_something)
p2 = multiprocessing.Process(target=do_something)

p1.start()
p2.start()

finish = time.perf_counter()

print(f'Finished in {round((finish - start), 2)} Seconds(s)')
# Out:
# Finished in 0.05 Seconds(s)

# %% [markdown]
# Join Method

# %%
import time
import multiprocessing

start = time.perf_counter()


def do_something():
    print('Sleeping 1 second.....')
    time.sleep(1)
    print('done sleeping')

p1 = multiprocessing.Process(target=do_something)
p2 = multiprocessing.Process(target=do_something)

p1.start()
p2.start()

p1.join()
p2.join()

finish = time.perf_counter()

print(f'Finished in {round((finish - start), 2)} Seconds(s)')
# Out:
# Finished in 0.13 Seconds(s)
